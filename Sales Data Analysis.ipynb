# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import chart_studio.plotly as py
import plotly.express as px
import plotly.graph_objects as go
import os

from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## How to read Feather Data

# %%
os.listdir()
# Out:
# ['Sales_data.ftr',
#  'Sales_analysis_Shan_Singh.ipynb',
#  '.ipynb_checkpoints',
#  'Sales Data Analysis.ipynb']

# %%
df = pd.read_feather("Sales_data.ftr")
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1          None                        None             None       None
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1          None    None             None       None       None
# 356        None    None             None       None       None
# 735        None    None             None       None       None
# 1433       None    None             None       None       None
# 1553       None    None             None       None       None
# ...         ...     ...              ...        ...        ...
# 185176     None    None             None       None       None
# 185438     None    None             None       None       None
# 186042     None    None             None       None       None
# 186548     None    None             None       None       None
# 186826     None    None             None       None       None
#
#        Purchase Address
# 1                  None
# 356                None
# 735                None
# 1433               None
# 1553               None
# ...                 ...
# 185176             None
# ...

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.duplicated().sum()
# Out:
# 618

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df = df.reset_index().drop(['index'],axis=1)
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185682   259353      AAA Batteries (4-pack)                3       2.99
# 185683   259354                      iPhone                1        700
# 185684   259355                      iPhone                1        700
# 185685   259356      34in Ultrawide Monitor                1     379.99
# 185686   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ## Analysing Monthly Sales

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185687 entries, 0 to 185686
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185687 non-null  object
#  1   Product           185687 non-null  object
#  2   Quantity Ordered  185687 non-null  object
#  3   Price Each        185687 non-null  object
#  4   Order Date        185687 non-null  object
#  5   Purchase Address  185687 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %%
df['Order Date'][0]
# Out:
# '04/19/19 08:46'

# %%
df['Order Date'][0].split(' ')[0].split('/')[0]
# Out:
# '04'

# %%
df['Order Date'][0].split('/')[0]
# Out:
# '04'

# %%
def get_month(x):
    return x.split('/')[0]

# %%
df['month']=df['Order Date'].apply(get_month)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185682   259353      AAA Batteries (4-pack)                3       2.99
# 185683   259354                      iPhone                1        700
# 185684   259355                      iPhone                1        700
# 185685   259356      34in Ultrawide Monitor                1     379.99
# 185686   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address month
# ...

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# month               object
# dtype: object

# %%
df = df[df.month!='Order Date']

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df.month = df.month.astype(int)

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185682   259353      AAA Batteries (4-pack)                3       2.99
# 185683   259354                      iPhone                1        700
# 185684   259355                      iPhone                1        700
# 185685   259356      34in Ultrawide Monitor                1     379.99
# 185686   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  month
# ...

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# month                int64
# dtype: object

# %%
df['Quantity Ordered'] = df['Quantity Ordered'].astype(int)
df['Price Each'] = df['Price Each'].astype(float)

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185682   259353      AAA Batteries (4-pack)                 3        2.99
# 185683   259354                      iPhone                 1      700.00
# 185684   259355                      iPhone                 1      700.00
# 185685   259356      34in Ultrawide Monitor                 1      379.99
# 185686   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month
# ...

# %%
df['sale']=df['Quantity Ordered']*df['Price Each']
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185682   259353      AAA Batteries (4-pack)                 3        2.99
# 185683   259354                      iPhone                 1      700.00
# 185684   259355                      iPhone                 1      700.00
# 185685   259356      34in Ultrawide Monitor                 1      379.99
# 185686   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month    sale
# ...

# %%
df.groupby(['month'])['sale'].sum()
# Out:
# month
# 1     1821413.16
# 2     2200078.08
# 3     2804973.35
# 4     3389217.98
# 5     3150616.23
# 6     2576280.15
# 7     2646461.32
# 8     2241083.37
# 9     2094465.69
# 10    3734777.86
# 11    3197875.05
# 12    4608295.70
# Name: sale, dtype: float64

# %%
df.groupby(['month'])['sale'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## Which city has Max order

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185682   259353      AAA Batteries (4-pack)                 3        2.99
# 185683   259354                      iPhone                 1      700.00
# 185684   259355                      iPhone                 1      700.00
# 185685   259356      34in Ultrawide Monitor                 1      379.99
# 185686   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month    sale
# ...

# %%
df = df.reset_index().drop(['index'],axis=1)
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185681   259353      AAA Batteries (4-pack)                 3        2.99
# 185682   259354                      iPhone                 1      700.00
# 185683   259355                      iPhone                 1      700.00
# 185684   259356      34in Ultrawide Monitor                 1      379.99
# 185685   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month    sale
# ...

# %%
df['city'] = [df['Purchase Address'][i].split(", ")[1] for i in range(df.shape[0])]

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185681   259353      AAA Batteries (4-pack)                 3        2.99
# 185682   259354                      iPhone                 1      700.00
# 185683   259355                      iPhone                 1      700.00
# 185684   259356      34in Ultrawide Monitor                 1      379.99
# 185685   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month  \
# ...

# %%
pd.value_counts(df['city']).plot(kind='pie', autopct = '%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Another way of plotting the above pie chart
df.city.value_counts().plot(kind='pie', autopct = '%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## What Product sold the most and why?

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185681   259353      AAA Batteries (4-pack)                 3        2.99
# 185682   259354                      iPhone                 1      700.00
# 185683   259355                      iPhone                 1      700.00
# 185684   259356      34in Ultrawide Monitor                 1      379.99
# 185685   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month  \
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'month', 'sale', 'city'],
#       dtype='object')

# %%
prod = df.groupby(['Product']).agg({'Quantity Ordered':'sum','Price Each':'mean'}).reset_index()
prod
# Out:
#                        Product  Quantity Ordered  Price Each
# 0                 20in Monitor              4126      109.99
# 1       27in 4K Gaming Monitor              6239      389.99
# 2             27in FHD Monitor              7541      149.99
# 3       34in Ultrawide Monitor              6192      379.99
# 4        AA Batteries (4-pack)             27615        3.84
# 5       AAA Batteries (4-pack)             30986        2.99
# 6     Apple Airpods Headphones             15637      150.00
# 7   Bose SoundSport Headphones             13430       99.99
# 8                Flatscreen TV              4813      300.00
# 9                 Google Phone              5529      600.00
# 10                    LG Dryer               646      600.00
# 11          LG Washing Machine               666      600.00
# 12    Lightning Charging Cable             23169       14.95
# 13          Macbook Pro Laptop              4725     1700.00
# ...

# %%
product_names = prod.Product.values
product_names
# Out:
# array(['20in Monitor', '27in 4K Gaming Monitor', '27in FHD Monitor',
#        '34in Ultrawide Monitor', 'AA Batteries (4-pack)',
#        'AAA Batteries (4-pack)', 'Apple Airpods Headphones',
#        'Bose SoundSport Headphones', 'Flatscreen TV', 'Google Phone',
#        'LG Dryer', 'LG Washing Machine', 'Lightning Charging Cable',
#        'Macbook Pro Laptop', 'ThinkPad Laptop', 'USB-C Charging Cable',
#        'Vareebadd Phone', 'Wired Headphones', 'iPhone'], dtype=object)

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(prod['Product'], prod['Quantity Ordered'],color='g')

ax2.plot(prod['Product'], prod['Price Each'])
ax1.set_xticklabels(product_names, rotation=90)

ax1.set_ylabel('Order Count')
ax2.set_ylabel('Average Price of Product')

plt.show()

# %% [markdown]
# ## Understanding Trend of the sales

# %%
df.head(3)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
#
#        Order Date                      Purchase Address  month    sale  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
#
#           city
# 0       Dallas
# 1       Boston
# 2  Los Angeles

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'month', 'sale', 'city'],
#       dtype='object')

# %%
pd.crosstab(df.month,df.Product).plot(figsize=(16,10))
# Out:
# <Axes: xlabel='month'>

# %%
most_sold_prod = df.Product.value_counts()[:5].index

# %%
filter = df.Product.isin(most_sold_prod)

# %%
most_sold_prod_df = df[filter]
most_sold_prod_df
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        176558    USB-C Charging Cable                 2       11.95
# 3        176560        Wired Headphones                 1       11.99
# 4        176561        Wired Headphones                 1       11.99
# 5        176562    USB-C Charging Cable                 1       11.95
# 7        176564    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 185676   259349  AAA Batteries (4-pack)                 1        2.99
# 185678   259350    USB-C Charging Cable                 1       11.95
# 185680   259352    USB-C Charging Cable                 1       11.95
# 185681   259353  AAA Batteries (4-pack)                 3        2.99
# 185685   259357    USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  month   sale  \
# ...

# %%
most_sold_prod_df.groupby(['month','Product']).size()
# Out:
# month  Product
# 1      AA Batteries (4-pack)       1037
#        AAA Batteries (4-pack)      1084
#        Lightning Charging Cable    1069
#        USB-C Charging Cable        1171
#        Wired Headphones            1004
# 2      AA Batteries (4-pack)       1274
#        AAA Batteries (4-pack)      1320
#        Lightning Charging Cable    1393
#        USB-C Charging Cable        1511
#        Wired Headphones            1179
# 3      AA Batteries (4-pack)       1672
#        AAA Batteries (4-pack)      1645
#        Lightning Charging Cable    1749
#        USB-C Charging Cable        1766
#        Wired Headphones            1512
# 4      AA Batteries (4-pack)       2062
#        AAA Batteries (4-pack)      1988
#        Lightning Charging Cable    2197
#        USB-C Charging Cable        2074
#        Wired Headphones            1888
# 5      AA Batteries (4-pack)       1821
#        AAA Batteries (4-pack)      1888
#        Lightning Charging Cable    1929
# ...

# %%
pivot = most_sold_prod_df.groupby(['month','Product']).size().unstack()
pivot
# Out:
# Product  AA Batteries (4-pack)  AAA Batteries (4-pack)  \
# month
# 1                         1037                    1084
# 2                         1274                    1320
# 3                         1672                    1645
# 4                         2062                    1988
# 5                         1821                    1888
# 6                         1540                    1451
# 7                         1555                    1554
# 8                         1357                    1340
# 9                         1314                    1281
# 10                        2240                    2234
# 11                        1970                    1999
# 12                        2716                    2828
#
# Product  Lightning Charging Cable  USB-C Charging Cable  Wired Headphones
# month
# 1                            1069                  1171              1004
# 2                            1393                  1511              1179
# ...

# %%
pivot.plot(figsize = (10,6))
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## What products are most often sold together?

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185681   259353      AAA Batteries (4-pack)                 3        2.99
# 185682   259354                      iPhone                 1      700.00
# 185683   259355                      iPhone                 1      700.00
# 185684   259356      34in Ultrawide Monitor                 1      379.99
# 185685   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month  \
# ...

# %%
df['Order ID']
# Out:
# 0         176558
# 1         176559
# 2         176560
# 3         176560
# 4         176561
#            ...
# 185681    259353
# 185682    259354
# 185683    259355
# 185684    259356
# 185685    259357
# Name: Order ID, Length: 185686, dtype: object

# %%
df_duplicated = df[df['Order ID'].duplicated(keep=False)]
df_duplicated
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 2        176560            Google Phone                 1      600.00
# 3        176560        Wired Headphones                 1       11.99
# 17       176574            Google Phone                 1      600.00
# 18       176574    USB-C Charging Cable                 1       11.95
# 30       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 185629   259303   AA Batteries (4-pack)                 1        3.84
# 185640   259314        Wired Headphones                 1       11.99
# 185641   259314  AAA Batteries (4-pack)                 2        2.99
# 185677   259350            Google Phone                 1      600.00
# 185678   259350    USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  month    sale  \
# ...

# %%
grouped_product_df = df_duplicated.groupby(['Order ID'])['Product'].apply(lambda x: ','.join(x)).reset_index().rename(columns = {'Product':'grouped_product'})

# %%
dup_prod_df = df_duplicated.merge(grouped_product_df,how='left',on='Order ID')
no_dup_df = dup_prod_df.drop_duplicates(subset=['Order ID'])
no_dup_df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       176560              Google Phone                 1      600.00
# 2       176574              Google Phone                 1      600.00
# 4       176586    AAA Batteries (4-pack)                 2        2.99
# 6       176672  Lightning Charging Cable                 1       14.95
# 8       176681  Apple Airpods Headphones                 1      150.00
# ...        ...                       ...               ...         ...
# 14118   259277                    iPhone                 1      700.00
# 14120   259297                    iPhone                 1      700.00
# 14122   259303    34in Ultrawide Monitor                 1      379.99
# 14124   259314          Wired Headphones                 1       11.99
# 14126   259350              Google Phone                 1      600.00
#
#            Order Date                        Purchase Address  month    sale  \
# ...

# %%
no_dup_df.grouped_product.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
no_dup_df.grouped_product.value_counts()[:5].plot(kind='pie',yla)
# Out:
# <Axes: ylabel='count'>
